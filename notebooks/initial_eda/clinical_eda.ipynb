# %% [markdown]
# # Initial Exploratory Data Analysis of Clinical Dataset
#
# Note: This EDA is done prior to merging the dataset with progression.csv. As such, within this EDA, the sole focus is on understanding the datasets statistical characteristics and features utilised.
#
# Following this analysis of all the individual datasets, there will be an EDA of all of the datasets merged, including progression.csv.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_pickle('../../data/processed/clinical.pkl.bz2', compression='bz2')
# Out:
# /var/folders/k4/6jgt4x2s2rx4xnxf88z6wtr00000gn/T/ipykernel_45118/4247536321.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data.columns
# Out:
# Index(['BP_DBP_mean', 'BP_HR_mean', 'BP_SBP_mean', 'Chair_StandUp_Stands',
#        'Chair_StandUp_Strategy', 'Menopause_Post', 'Painful_Hip',
#        'Self_Paced_Walk_Aid', 'Med_His_OA', 'PE_Doyle_Index',
#        'PE_Hand_Joints_Pain', 'PE_Hand_Joints_Pain_20d',
#        'PE_Hand_Osteoarthritis_Severity', 'BMI', 'Self_Paced_Walk_Time', 'CCI',
#        'OA_Medication', 'PE_Sum_Hands_Deformities',
#        'PE_Sum_Hands_Hard_Tissue_Enl', 'PE_Sum_Hands_Inflamed_Joints',
#        'PE_Sum_Hands_Osteophytes', 'PE_Thumb_MC_Subluxation_Ha',
#        'PE_Min_Hip_Flexion', 'PE_Min_Hip_Flexum',
#        'PE_Min_Hip_Rotation_External', 'PE_Min_Hip_Rotation_Internal',
#        'ROM_Min_Hip_Swing', 'PE_Knees_Effusion', 'PE_Min_Knees_Flexion',
#        'PE_Knees_Flexum', 'PE_Knees_Grinding_Pos_Test', 'PE_Knee_Valgus',
#        'PE_Knee_Varus', 'PE_Knee_Warmth', 'ROM_Min_Knee_Swing', 'ROM_Stance_K',
#        'Age', 'Sex'],
#       dtype='object')

# %%
data.shape
# Out:
# (297, 38)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 1528020110022 to 1528020110426
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   BP_DBP_mean                      297 non-null    float64
#  1   BP_HR_mean                       297 non-null    float64
#  2   BP_SBP_mean                      297 non-null    float64
#  3   Chair_StandUp_Stands             294 non-null    float64
#  4   Chair_StandUp_Strategy           297 non-null    category
#  5   Menopause_Post                   295 non-null    Int64
#  6   Painful_Hip                      267 non-null    category
#  7   Self_Paced_Walk_Aid              297 non-null    category
#  8   Med_His_OA                       297 non-null    category
#  9   PE_Doyle_Index                   290 non-null    float64
#  10  PE_Hand_Joints_Pain              297 non-null    category
#  11  PE_Hand_Joints_Pain_20d          255 non-null    category
#  12  PE_Hand_Osteoarthritis_Severity  297 non-null    category
#  13  BMI                              296 non-null    float64
#  14  Self_Paced_Walk_Time             297 non-null    float64
#  15  CCI                              297 non-null    float64
#  16  OA_Medication                    297 non-null    category
#  17  PE_Sum_Hands_Deformities         297 non-null    float64
#  18  PE_Sum_Hands_Hard_Tissue_Enl     297 non-null    float64
#  19  PE_Sum_Hands_Inflamed_Joints     297 non-null    float64
#  20  PE_Sum_Hands_Osteophytes         297 non-null    float64
#  21  PE_Thumb_MC_Subluxation_Ha       297 non-null    Int64
#  22  PE_Min_Hip_Flexion               297 non-null    Int64
#  23  PE_Min_Hip_Flexum                297 non-null    Int64
#  24  PE_Min_Hip_Rotation_External     297 non-null    Int64
#  25  PE_Min_Hip_Rotation_Internal     297 non-null    Int64
#  26  ROM_Min_Hip_Swing                283 non-null    float64
#  27  PE_Knees_Effusion                297 non-null    Int64
#  28  PE_Min_Knees_Flexion             297 non-null    Int64
#  29  PE_Knees_Flexum                  297 non-null    Int64
#  30  PE_Knees_Grinding_Pos_Test       297 non-null    Int64
#  31  PE_Knee_Valgus                   297 non-null    Int64
#  32  PE_Knee_Varus                    297 non-null    Int64
#  33  PE_Knee_Warmth                   297 non-null    Int64
#  34  ROM_Min_Knee_Swing               284 non-null    float64
#  35  ROM_Stance_K                     284 non-null    float64
#  36  Age                              297 non-null    int64
#  37  Sex                              297 non-null    category
# dtypes: Int64(13), category(9), float64(15), int64(1)
# memory usage: 76.1 KB

# %%
data.describe()
# Out:
#        BP_DBP_mean  BP_HR_mean  BP_SBP_mean  Chair_StandUp_Stands  \
# count   297.000000  297.000000   297.000000            294.000000
# mean     80.833333   71.659933   136.213805             10.302721
# std      11.755462   10.586620    19.557881              3.069201
# min      33.000000   43.000000    96.000000              2.000000
# 25%      74.000000   64.000000   122.000000              8.000000
# 50%      81.000000   71.500000   135.000000             10.000000
# 75%      88.000000   78.000000   147.000000             12.000000
# max     113.000000  101.500000   205.500000             26.000000
#
#        Menopause_Post  PE_Doyle_Index         BMI  Self_Paced_Walk_Time  \
# count           295.0      290.000000  296.000000            297.000000
# mean         0.515254        4.589655   28.062838             28.535354
# std          0.840476        7.730801    5.294081              7.740268
# min              -1.0        0.000000   18.300000             10.000000
# 25%               0.0        0.000000   24.375000             24.000000
# 50%               1.0        1.500000   27.000000             27.000000
# 75%               1.0        6.000000   31.600000             31.000000
# max               1.0       66.000000   47.500000             62.000000
#
#               CCI  PE_Sum_Hands_Deformities  ...  PE_Knees_Effusion  \
# count  297.000000                297.000000  ...              297.0
# mean     0.501684                  0.700337  ...           0.255892
# std      0.854735                  1.363533  ...           0.540746
# min      0.000000                  0.000000  ...                0.0
# 25%      0.000000                  0.000000  ...                0.0
# 50%      0.000000                  0.000000  ...                0.0
# 75%      1.000000                  1.000000  ...                0.0
# max      5.000000                  8.000000  ...                2.0
#
#        PE_Min_Knees_Flexion  PE_Knees_Flexum  PE_Knees_Grinding_Pos_Test  \
# count                 297.0            297.0                       297.0
# mean               2.670034         0.121212                    0.407407
# std                0.512227         0.417669                    0.651671
# min                     1.0              0.0                         0.0
# 25%                     2.0              0.0                         0.0
# 50%                     3.0              0.0                         0.0
# 75%                     3.0              0.0                         1.0
# max                     3.0              2.0                         2.0
#
#        PE_Knee_Valgus  PE_Knee_Varus  PE_Knee_Warmth  ROM_Min_Knee_Swing  \
# count           297.0          297.0           297.0          284.000000
# mean         0.121212       0.057239        0.074074           16.361620
# std          0.456323       0.272792        0.286936            4.917443
# min               0.0            0.0             0.0            2.300000
# 25%               0.0            0.0             0.0           12.875000
# 50%               0.0            0.0             0.0           16.300000
# 75%               0.0            0.0             0.0           19.800000
# max               2.0            2.0             2.0           29.100000
#
#        ROM_Stance_K         Age
# count    284.000000  297.000000
# mean      16.184859   66.508418
# std        5.180326    7.116366
# min        0.000000   44.000000
# 25%       12.875000   62.000000
# 50%       16.200000   68.000000
# 75%       20.100000   71.000000
# max       33.300000   82.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# ### Investigate Categorical Columns

# %%
categorical_cols = data.select_dtypes(include=['category', 'object']).columns

for col in categorical_cols:
    print(f"Value counts for {col}:")
    print(data[col].value_counts())
    print("\n")
# Out:
# Value counts for Chair_StandUp_Strategy:
# Chair_StandUp_Strategy
# 0    294
# 1      3
# Name: count, dtype: int64
#
#
# Value counts for Painful_Hip:
# Painful_Hip
# 1    200
# 2     67
# Name: count, dtype: int64
#
#
# Value counts for Self_Paced_Walk_Aid:
# Self_Paced_Walk_Aid
# 0    291
# 1      6
# Name: count, dtype: int64
#
#
# Value counts for Med_His_OA:
# Med_His_OA
# 0    200
# 1     97
# Name: count, dtype: int64
#
#
# Value counts for PE_Hand_Joints_Pain:
# PE_Hand_Joints_Pain
# 1    255
# 0     42
# Name: count, dtype: int64
#
#
# Value counts for PE_Hand_Joints_Pain_20d:
# PE_Hand_Joints_Pain_20d
# 1    132
# 0    123
# Name: count, dtype: int64
#
#
# Value counts for PE_Hand_Osteoarthritis_Severity:
# PE_Hand_Osteoarthritis_Severity
# 1    290
# 0      7
# Name: count, dtype: int64
#
#
# Value counts for OA_Medication:
# OA_Medication
# 0    285
# 1     12
# Name: count, dtype: int64
#
#
# Value counts for Sex:
# Sex
# 2    230
# 1     67
# Name: count, dtype: int64

# %% [markdown]
# ### Investigate Data Quality

# %%
# Check for missing data
data.isnull().sum()
# Out:
# BP_DBP_mean                         0
# BP_HR_mean                          0
# BP_SBP_mean                         0
# Chair_StandUp_Stands                3
# Chair_StandUp_Strategy              0
# Menopause_Post                      2
# Painful_Hip                        30
# Self_Paced_Walk_Aid                 0
# Med_His_OA                          0
# PE_Doyle_Index                      7
# PE_Hand_Joints_Pain                 0
# PE_Hand_Joints_Pain_20d            42
# PE_Hand_Osteoarthritis_Severity     0
# BMI                                 1
# Self_Paced_Walk_Time                0
# CCI                                 0
# OA_Medication                       0
# PE_Sum_Hands_Deformities            0
# PE_Sum_Hands_Hard_Tissue_Enl        0
# PE_Sum_Hands_Inflamed_Joints        0
# PE_Sum_Hands_Osteophytes            0
# PE_Thumb_MC_Subluxation_Ha          0
# PE_Min_Hip_Flexion                  0
# PE_Min_Hip_Flexum                   0
# PE_Min_Hip_Rotation_External        0
# PE_Min_Hip_Rotation_Internal        0
# ROM_Min_Hip_Swing                  14
# PE_Knees_Effusion                   0
# PE_Min_Knees_Flexion                0
# PE_Knees_Flexum                     0
# PE_Knees_Grinding_Pos_Test          0
# PE_Knee_Valgus                      0
# PE_Knee_Varus                       0
# PE_Knee_Warmth                      0
# ROM_Min_Knee_Swing                 13
# ROM_Stance_K                       13
# Age                                 0
# Sex                                 0
# dtype: int64

# %%
# Percentage of missing data
data.isnull().sum() * 100 / len(data)
# Out:
# BP_DBP_mean                         0.000000
# BP_HR_mean                          0.000000
# BP_SBP_mean                         0.000000
# Chair_StandUp_Stands                1.010101
# Chair_StandUp_Strategy              0.000000
# Menopause_Post                      0.673401
# Painful_Hip                        10.101010
# Self_Paced_Walk_Aid                 0.000000
# Med_His_OA                          0.000000
# PE_Doyle_Index                      2.356902
# PE_Hand_Joints_Pain                 0.000000
# PE_Hand_Joints_Pain_20d            14.141414
# PE_Hand_Osteoarthritis_Severity     0.000000
# BMI                                 0.336700
# Self_Paced_Walk_Time                0.000000
# CCI                                 0.000000
# OA_Medication                       0.000000
# PE_Sum_Hands_Deformities            0.000000
# PE_Sum_Hands_Hard_Tissue_Enl        0.000000
# PE_Sum_Hands_Inflamed_Joints        0.000000
# PE_Sum_Hands_Osteophytes            0.000000
# PE_Thumb_MC_Subluxation_Ha          0.000000
# PE_Min_Hip_Flexion                  0.000000
# PE_Min_Hip_Flexum                   0.000000
# PE_Min_Hip_Rotation_External        0.000000
# PE_Min_Hip_Rotation_Internal        0.000000
# ROM_Min_Hip_Swing                   4.713805
# PE_Knees_Effusion                   0.000000
# PE_Min_Knees_Flexion                0.000000
# PE_Knees_Flexum                     0.000000
# PE_Knees_Grinding_Pos_Test          0.000000
# PE_Knee_Valgus                      0.000000
# PE_Knee_Varus                       0.000000
# PE_Knee_Warmth                      0.000000
# ROM_Min_Knee_Swing                  4.377104
# ROM_Stance_K                        4.377104
# Age                                 0.000000
# Sex                                 0.000000
# dtype: float64

# %%
# Calculate percentage of missing values
missing_percentage = data.isnull().sum() * 100 / len(data)
missing_percentage = missing_percentage[missing_percentage > 0].sort_values(ascending=False)

plt.figure(figsize=(10, 6))
missing_percentage.plot(kind='bar')
plt.title('Percentage of Missing Values by Column')
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values')
plt.show()

# %%
missing = data.isnull()

sns.heatmap(missing, cbar=False, cmap="viridis")
plt.title("Distribution of Missing Data")
plt.show()

# %%
# Check for duplicated data
data.duplicated().sum()
# Out:
# 0

# %%
# Melt the dataset for visualisation purposes
data_melted = data.melt(value_vars=data.columns)

plt.figure(figsize=(16, 8))
sns.boxplot(x='variable', y='value', data=data_melted)
plt.title('Box Plots of Features')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Univariate Analysis

# %%
columns = data.select_dtypes(include=['int64', 'Int64', 'float64']).columns
features_per_fig = 4

# Iterate over the columns in steps of features_per_fig
for i in range(0, len(columns), features_per_fig):
    plt.figure(figsize=(15, 5))
    
    # Loop through the next set of features_per_fig features
    for j, col in enumerate(columns[i:i+features_per_fig], start=1):
        plt.subplot(1, features_per_fig, j)
        sns.histplot(data[col], kde=True)
        plt.title(f'{col} Distribution')
    
    plt.tight_layout()
    plt.show()

# %%
categorical_columns = data.select_dtypes(include=['category']).columns
features_per_fig = 3

# Iterate over the categorical columns in steps of features_per_fig
for i in range(0, len(categorical_columns), features_per_fig):
    plt.figure(figsize=(15, 5))
    
    # Loop through the next set of features_per_fig features
    for j, col in enumerate(categorical_columns[i:i+features_per_fig], start=1):
        plt.subplot(1, features_per_fig, j)
        sns.countplot(x=data[col])
        plt.title(f'{col} Count')
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Multivariant Analysis

# %%
corr = data.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=False, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
